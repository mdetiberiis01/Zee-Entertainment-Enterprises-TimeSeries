# %%
import pandas as pd 
import numpy as np
import glob

# %%
from nsepy import get_history
from datetime import date 
import nsepy

# %%
# setting the year and duration of data collection

from nsepy.derivatives import get_expiry_date
expiry = get_expiry_date(year=2019, month=12)
expiry
# Out:
# {datetime.date(2019, 12, 5),
#  datetime.date(2019, 12, 12),
#  datetime.date(2019, 12, 19),
#  datetime.date(2019, 12, 26)}

# %%
tcs = get_history(symbol='ZEEL',
                   start=date(2015,1,1),
                   end=date(2020,10,21))

# %%
tcs
# Out:
#            Symbol Series  Prev Close   Open    High     Low    Last   Close  \
# Date
# 2015-01-01   ZEEL     EQ      380.75  381.0  381.05  377.05  379.00  377.70
# 2015-01-02   ZEEL     EQ      377.70  378.0  383.50  378.00  379.50  380.95
# 2015-01-05   ZEEL     EQ      380.95  379.1  381.60  377.10  379.80  380.00
# 2015-01-06   ZEEL     EQ      380.00  377.0  378.45  361.20  369.95  367.90
# 2015-01-07   ZEEL     EQ      367.90  367.9  370.00  360.45  363.90  364.85
# ...           ...    ...         ...    ...     ...     ...     ...     ...
# 2020-10-15   ZEEL     EQ      186.20  187.0  188.40  178.70  180.20  179.95
# 2020-10-16   ZEEL     EQ      179.95  181.5  182.95  173.50  175.30  175.70
# 2020-10-19   ZEEL     EQ      175.70  176.7  177.90  173.50  174.20  174.20
# 2020-10-20   ZEEL     EQ      174.20  174.2  183.80  173.00  183.00  183.00
# 2020-10-21   ZEEL     EQ      183.00  185.0  189.20  176.05  181.00  180.55
#
# ...

# %%
# generate features 

#def features_build(df):
#     df['Date'] = pd.to_datetime(df['Date'])
#     df['Year'] = df['Date'].dt.year
#     df['Month'] = df.Date.dt.month
#     df['Day'] = df.Date.dt.day
#     df['WeekOfYear'] = df.Date.dt.weekofyear

# %%
#setting index as date

tcs.insert(0, 'Date',  pd.to_datetime(tcs.index,format='%Y-%m-%d') )

# %%
print(type(tcs.index))
print(type(tcs.Date))
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.series.Series'>

# %%
tcs
# Out:
#                  Date Symbol Series  Prev Close   Open    High     Low  \
# Date
# 2015-01-01 2015-01-01   ZEEL     EQ      380.75  381.0  381.05  377.05
# 2015-01-02 2015-01-02   ZEEL     EQ      377.70  378.0  383.50  378.00
# 2015-01-05 2015-01-05   ZEEL     EQ      380.95  379.1  381.60  377.10
# 2015-01-06 2015-01-06   ZEEL     EQ      380.00  377.0  378.45  361.20
# 2015-01-07 2015-01-07   ZEEL     EQ      367.90  367.9  370.00  360.45
# ...               ...    ...    ...         ...    ...     ...     ...
# 2020-10-15 2020-10-15   ZEEL     EQ      186.20  187.0  188.40  178.70
# 2020-10-16 2020-10-16   ZEEL     EQ      179.95  181.5  182.95  173.50
# 2020-10-19 2020-10-19   ZEEL     EQ      175.70  176.7  177.90  173.50
# 2020-10-20 2020-10-20   ZEEL     EQ      174.20  174.2  183.80  173.00
# 2020-10-21 2020-10-21   ZEEL     EQ      183.00  185.0  189.20  176.05
#
#               Last   Close    VWAP    Volume      Turnover  Trades  \
# Date
# ...

# %%
tcs.to_csv('/Users/markdetiberiis/Desktop/Stocks_data/tcs.csv')
